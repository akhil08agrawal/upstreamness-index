# %%
#Please read the comments properly before executing the code
# all the codes are in order hence the upper part must be taken care off properly
# before proceeding to the further section of the code


import zipfile
# archive = zipfile.ZipFile('images.zip', 'r')
# imgfile = archive.open('img_01.png')
import scipy.linalg
import pandas as pd
import numpy as np
import os
import shutil
from datetime import datetime

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from scipy.stats import mode
import numpy.matlib

def help():
  print("List of functions")
  print("load_dataset(yyyy)")
  print("cross_country_IO_table(list_one , yyyy)")
  print("self_IO_table(country_code , yyyy)")
  print("get_upstream_value(country_code,yyyy)")
  print("get_industry_code() : To get the various labels data")
  print("save_weighted_UI_and_gross_output(commonwealth_countries,end_year , save_file ) : returns huha")
  print("    ")
  print("the variables used")
  print("data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA")
  print("country_codes, country_list,industry_codes_26,industry_codes_6")
  print("data_FD, data_Q, data_T,data_VA,data_QY ")  
  print("label_FD,label_Q,label_T,label_VA ")
  print("country_codes, country_list,industry_codes_26,industry_codes_6")

commonwealth_countries = ['ATG' , 'AUS' , 'BHS' , 'BGD' , 'BRB' , 'BLZ' , 'BWA' , 'BRN' , 'CMR' , 'CAN' , 'CYP' , 'DOM' , 'FJI' , 'GMB' , 'GHA' , 'GUY' , 'IND' , 'JAM' , 'KEN' , 'LSO' , 'MWI' , 'MYS' , 'MLT' , 'MUS' , 'MOZ' , 'NAM' , 'NZL' , 'NGA' , 'PAK' , 'PNG' , 'RWA' , 'WSM' , 'SYC' , 'SLE' , 'SGP' , 'ZAF' , 'LKA' , 'SWZ' , 'TTO' , 'UGA' , 'GBR' , 'VUT' , 'ZMB']



def load_dataset(yyyy):
  file_name = "Eora26_" + str(yyyy) + "_bp" 

  # print("The data has been read from the directory")
  data = zipfile.ZipFile(file_name + '.zip','r')

  data_FD = data.open(file_name + '_FD.txt')
  data_Q = data.open(file_name + '_Q.txt')
  data_T = data.open(file_name + '_T.txt')
  data_VA = data.open(file_name + '_VA.txt')
  data_QY = data.open(file_name + '_QY.txt')

  label_FD = data.open('labels_FD.txt')
  label_Q = data.open('labels_Q.txt')
  label_T = data.open('labels_T.txt')
  label_VA = data.open('labels_VA.txt')

  data_FD = pd.read_csv( data_FD, sep="\t", header=None)
  data_Q = pd.read_csv( data_Q, sep="\t", header=None)
  data_T = pd.read_csv( data_T, sep="\t", header=None)
  data_VA = pd.read_csv( data_VA, sep="\t", header=None)
  data_QY = pd.read_csv( data_QY, sep="\t", header=None)

  # label_FD = pd.read_csv( label_FD, sep="\t", header=None)
  # label_Q = pd.read_csv( label_Q, sep="\t", header=None)
  # label_T = pd.read_csv( label_T, sep="\t", header=None)
  # label_VA = pd.read_csv( label_VA, sep="\t", header=None)

  # delim_whitespace=True

  label_FD = pd.read_csv( "labels_FD.txt", sep="\t", header=None)
  label_Q = pd.read_csv( "labels_Q.txt", sep="\t", header=None)
  label_T = pd.read_csv( "labels_T.txt", sep="\t", header=None)
  label_VA = pd.read_csv( "labels_VA.txt", sep="\t", header=None)

  # deleting useless column
  # df = df.drop('column_name', 1)
  labels = [label_FD , label_Q , label_T, label_VA]

  label_FD = label_FD.drop(4,1)
  label_Q = label_Q.drop(2,1)
  label_T = label_T.drop(4,1)
  label_VA = label_VA.drop(2,1)

  country_codes = label_FD[1].unique()
  # changing numpy array to list
  country_codes = np.ndarray.tolist(country_codes)
  # row_level_one = country_codes.index('CRI')

  country_list = label_FD[0].unique()
  # changing numpy array to list
  country_list = np.ndarray.tolist(country_list)

  industry_codes_26 = label_T[3].unique()
  industry_codes_26 = np.ndarray.tolist(industry_codes_26)
  industry_codes_26.remove('Total')

  industry_codes_6 = label_FD[3].unique()
  industry_codes_6 = np.ndarray.tolist(industry_codes_6)

  return data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA,country_codes, country_list,industry_codes_26,industry_codes_6


def get_industry_code(yyyy = 1990):
  file_name = "Eora26_" + str(yyyy) + "_bp" 

  # print("The data has been read from the directory")
  data = zipfile.ZipFile(file_name + '.zip','r')

#   data_FD = data.open(file_name + '_FD.txt')
#   data_Q = data.open(file_name + '_Q.txt')
#   data_T = data.open(file_name + '_T.txt')
#   data_VA = data.open(file_name + '_VA.txt')
#   data_QY = data.open(file_name + '_QY.txt')

  label_FD = data.open('labels_FD.txt')
  label_Q = data.open('labels_Q.txt')
  label_T = data.open('labels_T.txt')
  label_VA = data.open('labels_VA.txt')

#   data_FD = pd.read_csv( data_FD, sep="\t", header=None)
#   data_Q = pd.read_csv( data_Q, sep="\t", header=None)
#   data_T = pd.read_csv( data_T, sep="\t", header=None)
#   data_VA = pd.read_csv( data_VA, sep="\t", header=None)
#   data_QY = pd.read_csv( data_QY, sep="\t", header=None)

  # label_FD = pd.read_csv( label_FD, sep="\t", header=None)
  # label_Q = pd.read_csv( label_Q, sep="\t", header=None)
  # label_T = pd.read_csv( label_T, sep="\t", header=None)
  # label_VA = pd.read_csv( label_VA, sep="\t", header=None)

  # delim_whitespace=True

  label_FD = pd.read_csv( "labels_FD.txt", sep="\t", header=None)
  label_Q = pd.read_csv( "labels_Q.txt", sep="\t", header=None)
  label_T = pd.read_csv( "labels_T.txt", sep="\t", header=None)
  label_VA = pd.read_csv( "labels_VA.txt", sep="\t", header=None)

  # deleting useless column
  # df = df.drop('column_name', 1)
  labels = [label_FD , label_Q , label_T, label_VA]

  label_FD = label_FD.drop(4,1)
  label_Q = label_Q.drop(2,1)
  label_T = label_T.drop(4,1)
  label_VA = label_VA.drop(2,1)

  country_codes = label_FD[1].unique()
  # changing numpy array to list
  country_codes = np.ndarray.tolist(country_codes)
  # row_level_one = country_codes.index('CRI')

  country_list = label_FD[0].unique()
  # changing numpy array to list
  country_list = np.ndarray.tolist(country_list)

  industry_codes_26 = label_T[3].unique()
  industry_codes_26 = np.ndarray.tolist(industry_codes_26)
  industry_codes_26.remove('Total')

  industry_codes_6 = label_FD[3].unique()
  industry_codes_6 = np.ndarray.tolist(industry_codes_6)

  return country_codes, country_list,industry_codes_26,industry_codes_6 , label_Q , label_VA


def get_new_industry_20(industry_codes_26):

    new_industry_20 = industry_codes_26.copy()
    new_industry_20[0] = 'Agriculture,Hunting,Forestry and Fishing'
    new_industry_20[10] = 'Manufacturing, nec; recycling'
    new_industry_20[15] = 'Trade'


    #removing the unnecessary industries

    new_industry_20.remove('Fishing')
    new_industry_20.remove('Recycling')
    new_industry_20.remove('Retail Trade')
    new_industry_20.remove('Maintenance and Repair')
    new_industry_20.remove('Private Households')
    new_industry_20.remove('Re-export & Re-import')

    #Use list.pop(2) to remove items by index
    
    return new_industry_20

# industry_codes_20 = get_new_industry_20(industry_codes_26)
###################################
#Modifying arrays according the the new 20 industries
###########################################

def modify_array_data_for_20(data1):

    data = data1.copy()
    data[0] = data[0] + data[1]
    data[10] = data[10] + data[11]
    data[15] = data[15] + data[16]

    #deleting unwanted rows for deleted industries from the backside
    data = np.delete(data,25)
    data = np.delete(data,23)
    data = np.delete(data,16)
    data = np.delete(data,14)
    data = np.delete(data,11)
    data = np.delete(data,1)

    return data


country_codes, country_list,industry_codes_26,industry_codes_6 , label_Q , label_VA = get_industry_code()
industry_codes_20 = get_new_industry_20(industry_codes_26)

# %%
country = 'IND'
yyyy = 2008
row_level_one = country_codes.index(country)
print(row_level_one)

ncntry  = 189
nsec    = 26
nfd     = 6

def dva_calculations_loop(country, yyyy, row_level_one,industry_codes_26):
    
    start = datetime.now()
    
        # %% Parameters

    ncntry  = 189
    nsec    = 26
    nfd     = 6

    # %% EORA Loop

    data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA,country_codes, country_list,industry_codes_26,industry_codes_6 = load_dataset(yyyy)


    # data_FD[data_FD < 0] = 0
    # data_T[data_T < 0] = 0

    FD = np.sum(np.reshape(data_FD.values,(ncntry*nsec+1, nfd,-1), order='F'),axis=1)        # 1140 columns
    FD = pd.DataFrame(FD)

    va_total_cs = np.sum(data_VA , axis =0)
    va_total_cs = np.asarray(va_total_cs)

    #Intermediate Demand
    GRTR_INT_cs_cs = data_T.iloc[0:ncntry*nsec,0:ncntry*nsec]
    #Final Demand
    GRTR_FNL_cs_c = FD.iloc[0:ncntry*nsec,0:ncntry]
    #Value added
    VALU_cs = va_total_cs[0:ncntry*nsec]


    #  (B) Identity matrices for summing across sectors (when calculating totals by country)

    imtx_cs_c= np.ones((nsec,1))
    ivector=np.ones((nsec,1))
    for i in range(0,ncntry -1):
        imtx_cs_c = scipy.linalg.block_diag(imtx_cs_c, ivector)
    imtx_cs_c = pd.DataFrame(imtx_cs_c)

    imtx_cs_cs= np.ones((nsec,nsec))
    ivector=np.ones((nsec,nsec))
    for i in range(0,ncntry -1):
        imtx_cs_cs = scipy.linalg.block_diag(imtx_cs_cs, ivector)
    imtx_cs_cs = pd.DataFrame(imtx_cs_cs)


    imtx_c_cs= np.ones((1,nsec))
    ivector = np.ones((1,nsec))
    for i in range(0,ncntry -1):
        imtx_c_cs = scipy.linalg.block_diag(imtx_c_cs, ivector)
    imtx_c_cs = pd.DataFrame(imtx_c_cs)


    imtx_c_c= np.eye(ncntry)
    imtx_c_c = pd.DataFrame(imtx_c_c)

    imtx_cs_ck= np.ones((nsec,nfd))
    ivector=np.ones((nsec,nfd))
    for i in range(0,ncntry -1):
        imtx_cs_ck = scipy.linalg.block_diag(imtx_cs_ck, ivector)
    imtx_cs_ck = pd.DataFrame(imtx_cs_ck)

    #  (C) Calculating Gross Ouput (GO)

    # Without statistical discrepancy

    GO_INT_part = np.sum(np.reshape(GRTR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
    GO_INT_part = pd.DataFrame(GO_INT_part)

    GO_cs_c = GO_INT_part + GRTR_FNL_cs_c
    GO_cs = np.sum(GO_cs_c,axis=1)
    GO_cs = np.asarray(GO_cs).reshape(4914,1)

    ################################
    GGO_INT_part = np.sum(GRTR_INT_cs_cs, axis =0)
    GGO_cs = GGO_INT_part + VALU_cs
    GGO_cs = np.asarray(GGO_cs).reshape(4914,1)
    ###############################

    GO_c_c = np.dot(imtx_c_cs,GO_cs_c)
    GO_c = np.sum(np.multiply(np.matlib.repmat(GO_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    VALU_cs = np.asarray(VALU_cs).reshape(4914,1)
    VALU_c = np.sum(np.multiply(np.matlib.repmat(VALU_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    Inputs_cs = np.sum(GRTR_INT_cs_cs,axis=0)
    Inputs_cs = np.asarray(Inputs_cs).reshape(4914,1)
    Inputs_c = np.sum(np.multiply(np.matlib.repmat(Inputs_cs, 1, ncntry),imtx_cs_c) ,axis=0)
    VALU_derived_cs = GO_cs - Inputs_cs
    VALU_derived_cs = np.asarray(VALU_derived_cs).reshape(4914,1)

    VALU_derived_c = np.sum(np.multiply(np.matlib.repmat(VALU_derived_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    # (E) Gross Exports
    #  Gross exports of intermediate goods and services from domestic
    #  sector s in country c

    EXGR_INT_cs_cs = np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec)) - imtx_cs_cs))

    EXGR_INT_cs_c = np.sum(np.reshape(EXGR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
    EXGR_INT_cs_c = pd.DataFrame(EXGR_INT_cs_c)


    EXGR_INT_cs = np.sum(EXGR_INT_cs_c,axis = 1)
    temp_EXGR_INT_cs = EXGR_INT_cs.copy()
    EXGR_INT_cs = np.asarray(EXGR_INT_cs).reshape(4914,1)
    EXGR_INT_c = np.sum(np.multiply(np.matlib.repmat(EXGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    # % Gross exports of final demand goods and services from domestic
    # sector s in country c

    EXGR_FNL_cs_c =np.multiply(GRTR_FNL_cs_c ,(np.ones((ncntry*nsec,ncntry)) - imtx_cs_c))
    EXGR_FNL_cs = np.sum(np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry)) - imtx_cs_c)), axis =1)
    temp_EXGR_FNL_cs = EXGR_FNL_cs.copy()
    EXGR_FNL_cs = np.asarray(EXGR_FNL_cs).reshape(4914,1)

    EXGR_FNL_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FNL_cs, 1, ncntry),imtx_cs_c) ,axis=0)
    EXGR_cs_c = EXGR_INT_cs_c + EXGR_FNL_cs_c
    EXGR_c_c = np.dot(imtx_c_cs,EXGR_cs_c)

    # % Total gross exports (country-sector x 1)
    EXGR_cs = temp_EXGR_INT_cs + temp_EXGR_FNL_cs

    # % Total gross exports (country x 1)
    EXGR_c = EXGR_INT_c + EXGR_FNL_c


    # %% (F) Gross Imports: (Imported Intermediates)
    # % Gross Imports of Intermediates (by country-sector, and by country)

    IMGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis =0)
    IMGR_INT_cs = np.asarray(IMGR_INT_cs).reshape(4914,1)
    IMGR_INT_c = np.sum(np.multiply(np.matlib.repmat(IMGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)


    #  % Gross Imports of Final Demand goods and services (by country)
    IMGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c, (np.ones((ncntry*nsec,ncntry))-imtx_cs_c)), axis = 0)

    # % Total gross imports (by country)
    IMGR_c = IMGR_INT_c + IMGR_FNL_c
    #an array of 189 elements

    # %% (G) Gross trade balance

    BALGR_c = EXGR_c - IMGR_c

    # %% (H) Demand for Domestic Inputs (Use of Domestic Intermediates)

    # % Gross Domestic Intermediate demand for domestic inputs by country-sector
    DDGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs , imtx_cs_cs),axis = 0)
    DDGR_INT_cs = np.asarray(DDGR_INT_cs).reshape(4914,1)
    DDGR_INT_c = np.sum(np.multiply(np.matlib.repmat(DDGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)


    # % Gross Domestic Final demand of domestic inputs by country-sector
    DDGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c,imtx_cs_c),axis = 0)


    # %% (I) Domestic and Foreign Final Demand

    GRTR_FNL_DOM_cs_c = np.multiply(GRTR_FNL_cs_c,imtx_cs_c)
    GRTR_FNL_DOM_cs = np.sum(GRTR_FNL_DOM_cs_c,axis = 1)

    # B)  Without statistical discrepancy

    # % By sector
    GRTR_FNL_DOM_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], imtx_cs_ck)
    # % Sum across the thrid dimension, across countries for each of the 6 components of final demand
    GRTR_FNL_DOM_cs_nfd = np.sum(np.reshape(GRTR_FNL_DOM_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis = 2)


    GRTR_FNL_FOR_cs_c = np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry))-imtx_cs_c))
    GRTR_FNL_FOR_cs = np.sum(GRTR_FNL_FOR_cs_c,axis=1)


    # % By sector
    GRTR_FNL_FOR_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], (np.ones((ncntry*nsec,ncntry*nfd))-imtx_cs_ck))
    # % Sum across the thrid dimension, across countries for each of the 6 components of final demand
    GRTR_FNL_FOR_cs_nfd = np.sum(np.reshape(GRTR_FNL_FOR_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis=2)


    # %% (J) Compute the VA vector indirectly (just to check that no problems with inverses)


    # abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
    # d = np.transpose(abc)
    # d

    GO_cs = np.asarray(GO_cs).reshape(4914,1)
    GGO_cs[4106] = 1

    abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
    Amat = np.divide(GRTR_INT_cs_cs ,np.transpose(abc))

    Amat = Amat.fillna(0)
    Amat[Amat < 0] = 0

    # % VA shares

    va_vec_cs = np.ones((nsec*ncntry,1)) - np.asarray(np.sum(Amat,axis=0)).reshape(nsec*ncntry,1)
    V_hat = np.eye(ncntry*nsec) - np.diag(np.sum(Amat , axis=0))

    # % Leontief inverse
    IminusA=np.eye(ncntry*nsec)-Amat
    Bmat=np.linalg.inv(IminusA)
    # % Leontief inverse

    # % Total Value Added by country-sector
    BY=np.matmul(Bmat,np.sum(GRTR_FNL_cs_c,axis=1))
    va_cs= np.multiply(va_vec_cs,BY)

    va_vec_cs = np.ones((nsec*ncntry,1)) - np.asarray(np.sum(Amat,axis=0)).reshape(nsec*ncntry,1)
    V_hat = np.eye(ncntry*nsec) - np.diag(np.sum(Amat , axis=0))

    # % Leontief inverse
    IminusA=np.eye(ncntry*nsec)-Amat
    Bmat=np.linalg.inv(IminusA)
    # % Leontief inverse

    # % Total Value Added by country-sector
    BY=np.matmul(Bmat,np.sum(GRTR_FNL_cs_c,axis=1))
    va_cs= np.multiply(va_vec_cs,BY)

    # %% (K) DVA and FVA of gross exports (From V*B*E)

    TiVA_temp = np.matmul(V_hat,Bmat)
    TiVA=np.matmul( TiVA_temp,np.diag(EXGR_cs))

    EXGR_DVA_cs = np.sum(np.multiply(TiVA,imtx_cs_cs), axis=0)
    EXGR_DVA_cs = np.asarray(EXGR_DVA_cs).reshape(4914,1)

    EXGR_FVA_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=0)
    EXGR_FVA_cs = np.asarray(EXGR_FVA_cs).reshape(4914,1)
    
    EXGR_DVX_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=1)
    EXGR_DVX_cs = np.asarray(EXGR_DVX_cs).reshape(4914,1)

    # EXGR_DVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_DVA_cs, 1, ncntry), imtx_cs_c),axis=0)
    # EXGR_FVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FVA_cs, 1, ncntry), imtx_cs_c),axis=0)

    EXGR_cs = np.asarray(EXGR_cs).reshape(4914,1)

    DVA_country = EXGR_DVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    FVA_country = EXGR_FVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    DVX_country = EXGR_DVX_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    GO_country = GO_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    GE_country = EXGR_cs[nsec*row_level_one:nsec*(row_level_one+1)]

    DVA_country_modified = modify_array_data_for_20(DVA_country)
    FVA_country_modified = modify_array_data_for_20(FVA_country)
    DVX_country_modified = modify_array_data_for_20(DVX_country)
    GE_country_modified = modify_array_data_for_20(GE_country)
    GO_country_modified = modify_array_data_for_20(GO_country)

    FWL = DVA_country_modified/GE_country_modified
    BWL = FVA_country_modified/GE_country_modified

    #GVC participation index
    temp_gvc = DVX_country_modified + FVA_country_modified

    GVC_index = temp_gvc/GE_country_modified
    FWL_BWL_ratio = FWL/BWL
    
    export_intensity = GE_country_modified/GO_country_modified
    
    
    end = datetime.now() - start

    return EXGR_DVA_cs, EXGR_FVA_cs,GO_cs,EXGR_cs,FWL,BWL,GVC_index,FWL_BWL_ratio,DVA_country_modified,FVA_country_modified, DVX_country_modified,GE_country_modified,end,GO_country_modified , export_intensity
# Out:
# 78

# %%
def calculate_UI(country, yyyy, row_level_one,industry_codes_26):
    
    start = datetime.now()


    data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA,country_codes, country_list,industry_codes_26,industry_codes_6 = load_dataset(yyyy)


    # data_FD[data_FD < 0] = 0
    # data_T[data_T < 0] = 0

    FD = np.sum(np.reshape(data_FD.values,(ncntry*nsec+1, nfd,-1), order='F'),axis=1)        # 1140 columns
    FD = pd.DataFrame(FD)

    va_total_cs = np.sum(data_VA , axis =0)
    va_total_cs = np.asarray(va_total_cs)

    #Intermediate Demand
    GRTR_INT_cs_cs = data_T.iloc[0:ncntry*nsec,0:ncntry*nsec]
    #Final Demand
    GRTR_FNL_cs_c = FD.iloc[0:ncntry*nsec,0:ncntry]
    #Value added
    VALU_cs = va_total_cs[0:ncntry*nsec]


    #  (B) Identity matrices for summing across sectors (when calculating totals by country)

    imtx_cs_c= np.ones((nsec,1))
    ivector=np.ones((nsec,1))
    for i in range(0,ncntry -1):
        imtx_cs_c = scipy.linalg.block_diag(imtx_cs_c, ivector)
    imtx_cs_c = pd.DataFrame(imtx_cs_c)

    imtx_cs_cs= np.ones((nsec,nsec))
    ivector=np.ones((nsec,nsec))
    for i in range(0,ncntry -1):
        imtx_cs_cs = scipy.linalg.block_diag(imtx_cs_cs, ivector)
    imtx_cs_cs = pd.DataFrame(imtx_cs_cs)


    imtx_c_cs= np.ones((1,nsec))
    ivector = np.ones((1,nsec))
    for i in range(0,ncntry -1):
        imtx_c_cs = scipy.linalg.block_diag(imtx_c_cs, ivector)
    imtx_c_cs = pd.DataFrame(imtx_c_cs)


    imtx_c_c= np.eye(ncntry)
    imtx_c_c = pd.DataFrame(imtx_c_c)

    imtx_cs_ck= np.ones((nsec,nfd))
    ivector=np.ones((nsec,nfd))
    for i in range(0,ncntry -1):
        imtx_cs_ck = scipy.linalg.block_diag(imtx_cs_ck, ivector)
    imtx_cs_ck = pd.DataFrame(imtx_cs_ck)

    #  (C) Calculating Gross Ouput (GO)

    # Without statistical discrepancy

    GO_INT_part = np.sum(np.reshape(GRTR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
    GO_INT_part = pd.DataFrame(GO_INT_part)

    GO_cs_c = GO_INT_part + GRTR_FNL_cs_c
    GO_cs = np.sum(GO_cs_c,axis=1)
    GO_cs = np.asarray(GO_cs).reshape(4914,1)

    ################################
    GGO_INT_part = np.sum(GRTR_INT_cs_cs, axis =0)
    GGO_cs = GGO_INT_part + VALU_cs
    GGO_cs = np.asarray(GGO_cs).reshape(4914,1)
    ###############################

    GO_c_c = np.dot(imtx_c_cs,GO_cs_c)
    GO_c = np.sum(np.multiply(np.matlib.repmat(GO_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    VALU_cs = np.asarray(VALU_cs).reshape(4914,1)
    VALU_c = np.sum(np.multiply(np.matlib.repmat(VALU_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    Inputs_cs = np.sum(GRTR_INT_cs_cs,axis=0)
    Inputs_cs = np.asarray(Inputs_cs).reshape(4914,1)
    Inputs_c = np.sum(np.multiply(np.matlib.repmat(Inputs_cs, 1, ncntry),imtx_cs_c) ,axis=0)
    VALU_derived_cs = GO_cs - Inputs_cs
    VALU_derived_cs = np.asarray(VALU_derived_cs).reshape(4914,1)

    VALU_derived_c = np.sum(np.multiply(np.matlib.repmat(VALU_derived_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    # (E) Gross Exports
    #  Gross exports of intermediate goods and services from domestic
    #  sector s in country c

    EXGR_INT_cs_cs = np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec)) - imtx_cs_cs))

    EXGR_INT_cs_c = np.sum(np.reshape(EXGR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
    EXGR_INT_cs_c = pd.DataFrame(EXGR_INT_cs_c)


    EXGR_INT_cs = np.sum(EXGR_INT_cs_c,axis = 1)
    temp_EXGR_INT_cs = EXGR_INT_cs.copy()
    EXGR_INT_cs = np.asarray(EXGR_INT_cs).reshape(4914,1)
    EXGR_INT_c = np.sum(np.multiply(np.matlib.repmat(EXGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)

    # % Gross exports of final demand goods and services from domestic
    # sector s in country c

    EXGR_FNL_cs_c =np.multiply(GRTR_FNL_cs_c ,(np.ones((ncntry*nsec,ncntry)) - imtx_cs_c))
    EXGR_FNL_cs = np.sum(np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry)) - imtx_cs_c)), axis =1)
    temp_EXGR_FNL_cs = EXGR_FNL_cs.copy()
    EXGR_FNL_cs = np.asarray(EXGR_FNL_cs).reshape(4914,1)

    EXGR_FNL_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FNL_cs, 1, ncntry),imtx_cs_c) ,axis=0)
    EXGR_cs_c = EXGR_INT_cs_c + EXGR_FNL_cs_c
    EXGR_c_c = np.dot(imtx_c_cs,EXGR_cs_c)

    # % Total gross exports (country-sector x 1)
    EXGR_cs = temp_EXGR_INT_cs + temp_EXGR_FNL_cs

    # % Total gross exports (country x 1)
    EXGR_c = EXGR_INT_c + EXGR_FNL_c


    # %% (F) Gross Imports: (Imported Intermediates)
    # % Gross Imports of Intermediates (by country-sector, and by country)

    IMGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis =0)
    IMGR_INT_cs = np.asarray(IMGR_INT_cs).reshape(4914,1)
    IMGR_INT_c = np.sum(np.multiply(np.matlib.repmat(IMGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)


    #  % Gross Imports of Final Demand goods and services (by country)
    IMGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c, (np.ones((ncntry*nsec,ncntry))-imtx_cs_c)), axis = 0)

    # % Total gross imports (by country)
    IMGR_c = IMGR_INT_c + IMGR_FNL_c
    #an array of 189 elements

    # %% (G) Gross trade balance

    BALGR_c = EXGR_c - IMGR_c

    # %% (H) Demand for Domestic Inputs (Use of Domestic Intermediates)

    # % Gross Domestic Intermediate demand for domestic inputs by country-sector
    DDGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs , imtx_cs_cs),axis = 0)
    DDGR_INT_cs = np.asarray(DDGR_INT_cs).reshape(4914,1)
    DDGR_INT_c = np.sum(np.multiply(np.matlib.repmat(DDGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)


    # % Gross Domestic Final demand of domestic inputs by country-sector
    DDGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c,imtx_cs_c),axis = 0)


    # %% (I) Domestic and Foreign Final Demand

    GRTR_FNL_DOM_cs_c = np.multiply(GRTR_FNL_cs_c,imtx_cs_c)
    GRTR_FNL_DOM_cs = np.sum(GRTR_FNL_DOM_cs_c,axis = 1)

    # B)  Without statistical discrepancy

    # % By sector
    GRTR_FNL_DOM_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], imtx_cs_ck)
    # % Sum across the thrid dimension, across countries for each of the 6 components of final demand
    GRTR_FNL_DOM_cs_nfd = np.sum(np.reshape(GRTR_FNL_DOM_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis = 2)


    GRTR_FNL_FOR_cs_c = np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry))-imtx_cs_c))
    GRTR_FNL_FOR_cs = np.sum(GRTR_FNL_FOR_cs_c,axis=1)


    # % By sector
    GRTR_FNL_FOR_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], (np.ones((ncntry*nsec,ncntry*nfd))-imtx_cs_ck))
    # % Sum across the thrid dimension, across countries for each of the 6 components of final demand
    GRTR_FNL_FOR_cs_nfd = np.sum(np.reshape(GRTR_FNL_FOR_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis=2)


    # %% (J) Compute the VA vector indirectly (just to check that no problems with inverses)


    # abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
    # d = np.transpose(abc)
    # d

    GO_cs = np.asarray(GO_cs).reshape(4914,1)
    GGO_cs[4106] = 1

    abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
    Amat = np.divide(GRTR_INT_cs_cs ,np.transpose(abc))

    Amat = Amat.fillna(0)
    Amat[Amat < 0] = 0

    # % VA shares

    va_vec_cs = np.ones((nsec*ncntry,1)) - np.asarray(np.sum(Amat,axis=0)).reshape(nsec*ncntry,1)
    V_hat = np.eye(ncntry*nsec) - np.diag(np.sum(Amat , axis=0))

    # % Leontief inverse
    IminusA=np.eye(ncntry*nsec)-Amat
    Bmat=np.linalg.inv(IminusA)
    # % Leontief inverse

    # % Total Value Added by country-sector
    BY=np.matmul(Bmat,np.sum(GRTR_FNL_cs_c,axis=1))
    va_cs= np.multiply(va_vec_cs,BY)

    va_vec_cs = np.ones((nsec*ncntry,1)) - np.asarray(np.sum(Amat,axis=0)).reshape(nsec*ncntry,1)
    V_hat = np.eye(ncntry*nsec) - np.diag(np.sum(Amat , axis=0))

    # %% (K) DVA and FVA of gross exports (From V*B*E)

    TiVA_temp = np.matmul(V_hat,Bmat)
    TiVA=np.matmul( TiVA_temp,np.diag(EXGR_cs))

    EXGR_DVA_cs = np.sum(np.multiply(TiVA,imtx_cs_cs), axis=0)
    EXGR_DVA_cs = np.asarray(EXGR_DVA_cs).reshape(4914,1)

    EXGR_FVA_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=0)
    EXGR_FVA_cs = np.asarray(EXGR_FVA_cs).reshape(4914,1)

    # EXGR_DVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_DVA_cs, 1, ncntry), imtx_cs_c),axis=0)
    # EXGR_FVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FVA_cs, 1, ncntry), imtx_cs_c),axis=0)

    EXGR_cs = np.asarray(EXGR_cs).reshape(4914,1)

    DVA_country = EXGR_DVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    FVA_country = EXGR_FVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    GO_country = GO_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    GE_country = EXGR_cs[nsec*row_level_one:nsec*(row_level_one+1)]
    GI_country = IMGR_INT_cs[nsec*row_level_one:nsec*(row_level_one+1)]

    DVA_country_modified = modify_array_data_for_20(DVA_country)
    FVA_country_modified = modify_array_data_for_20(FVA_country)
    GE_country_modified = modify_array_data_for_20(GE_country)

    FWL = DVA_country_modified/GE_country_modified
    BWL = FVA_country_modified/GE_country_modified

    #GVC participation index

    GVC_index = ((FWL + BWL) * 100)/GE_country_modified
    FWL_BWL_ratio = FWL/BWL

    #UPstreamness calculation
    UI2_temp = np.matmul(Bmat,GO_cs)
    UI2 = UI2_temp/GO_cs
    UI2_country = UI2[nsec*row_level_one:nsec*(row_level_one+1)]

    #calculating UI for 20 industries


    GO_country_modified = modify_array_data_for_20(GO_country)
    GO_country_modified = GO_country_modified.reshape(20,1)
    temp1 = GRTR_INT_cs_cs.iloc[nsec*row_level_one:nsec*(row_level_one+1),nsec*row_level_one:nsec*(row_level_one+1)].copy()
    ###################################
    #Converting the data from 26 industries to 20 industries
    ###########################################

    #Reducing Industries

    #sn = starting number .... number for the first industry which is Agriculture
    sn = row_level_one*26

    #Adding Industry 1 & 2 ....i.e. Agriculture and Fishing
    #Rename as Agriculture,Hunting,Forestry and Fishing
    temp1[sn] = temp1[sn] + temp1[sn+1]
    # deleting useless column
    # df = df.drop('column_name', 1)

    temp1 = temp1.drop(sn+1,1)
    #deleting the fishing column

    #Adding Industry 11 & 12 ....i.e. Other Manufacturing and Recycling
    #Rename as Manufacturing, nec; recycling
    temp1[sn+10] = temp1[sn+10] + temp1[sn+11]
    temp1 = temp1.drop(sn+11,1)#deleting the Recycling column

    #Deleting maintainance and repair (15), Private Households (24) and Re-export & Re-import (26)
    temp1 = temp1.drop(sn+14,1) 
    temp1 = temp1.drop(sn+23,1)
    temp1 = temp1.drop(sn+25,1)

    #Adding Industry 16 & 17 ....i.e. wholesale trade and retail trade.....
    #Rename as Trade
    temp1[sn+15] = temp1[sn+15] + temp1[sn+16]
    temp1 = temp1.drop(sn+16,1)#deleting the Recycling column

    #The new table with modified industries is ready column wise

    #Now we need to add the data in similar fashion row wise


    #Adding Industry 1 & 2 ....i.e. Agriculture and Fishing
    #Rename as Agriculture,Hunting,Forestry and Fishing
    temp1.loc[sn] = temp1.loc[sn] + temp1.loc[sn+1]

    temp1 = temp1.drop(sn+1,0)#deleting the fishing column

    temp1.loc[sn+10] = temp1.loc[sn+10] + temp1.loc[sn+11]
    temp1 = temp1.drop(sn+11,0)#deleting the Recycling column

    #Deleting maintainance and repair (15), Private Households (24) and Re-export & Re-import (26)
    temp1 = temp1.drop(sn+14,0) 
    temp1 = temp1.drop(sn+23,0)
    temp1 = temp1.drop(sn+25,0)

    #Adding Industry 16 & 17 ....i.e. wholesale trade and retail trade.....
    #Rename as Trade
    temp1.loc[sn+15] = temp1.loc[sn+15] + temp1.loc[sn+16]
    temp1 = temp1.drop(sn+16,0)


    #THe modified Input output table is ready
    # io_table = temp1.copy()


    abc_new = np.matlib.repmat(GO_country_modified, 1, len(GO_country_modified))
    # abc_new = pd.DataFrame(abc_new)
    temp1 = temp1.to_numpy()
    Amat_new = np.divide(temp1 ,np.transpose(abc_new))

    # % Leontief inverse
    IminusA_ = np.eye(20)-Amat_new
    Bmat_new =np.linalg.inv(IminusA_)

    UI1_temp = np.matmul(Bmat_new,GO_country_modified)
    UI1_country_20 = UI1_temp/GO_country_modified

    return UI1_country_20 , UI2_country , UI2

# %%
UI1_country_20 , UI2_country , UI2 = calculate_UI(country, yyyy, row_level_one,industry_codes_26)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:245: RuntimeWarning: invalid value encountered in true_divide

# %%
country = 'IND'
yyyy = 2008
row_level_one = country_codes.index(country)
print(row_level_one)
# Out:
# 78

# %%
country = 'IND'
# yyyy = 2008
row_level_one = country_codes.index(country)
# print(row_level_one)

a = np.arange(0,4914)

UI_master_file = pd.DataFrame(a)

UI2_c = pd.DataFrame(industry_codes_26)
UI1_c = pd.DataFrame(industry_codes_20)


UI2_c = UI2_c.rename(columns={ 0 : country})
UI1_c = UI1_c.rename(columns={ 0 : country})


start_year = 1990
end_year = 2015

start1 = datetime.now()

for i in range(start_year,end_year+1):
    
    UI1_country_20 , UI2_country , UI2 = calculate_UI(country, i, row_level_one,industry_codes_26)

    UI_master_file[i] = UI2.copy()
    
    UI2_c[i] = UI2_country.copy()
    UI1_c[i] = UI1_country_20.copy()
    
    print("the year ",i)
    

filename_a = "Z_Master_file_UI" + ".csv"
filename_b = "Z_" + str(country) + "_UI2" + ".csv"
filename_c = "Z_" + str(country) + "_UI_20_industries" + ".csv"


UI_master_file.to_csv(filename_a, index= False)
UI2_c.to_csv(filename_b, index= False)
UI1_c.to_csv(filename_c, index= False)


# DVA_country, FVA_country,GO_country,GE_country,FWL,BWL,GVC_index,FWL_BWL_ratio,DVA_country_modified,FVA_country_modified, GE_country_modified,end = dva_calculations_loop(country, yyyy, row_level_one,industry_codes_26) 

end = datetime.now()
print(end - start1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:245: RuntimeWarning: invalid value encountered in true_divide
# the year  1990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-98baf67c26d2> in <module>()
#      23 for i in range(start_year,end_year+1):
#      24
# ---> 25     UI1_country_20 , UI2_country , UI2 = calculate_UI(country, i, row_level_one,industry_codes_26)
#      26
#      27     UI_master_file[i] = UI2.copy()
#
# <ipython-input-3-64184375de3f> in calculate_UI(country, yyyy, row_level_one, industry_codes_26)
#      35     ivector=np.ones((nsec,nsec))
#      36     for i in range(0,ncntry -1):
# ---> 37         imtx_cs_cs = scipy.linalg.block_diag(imtx_cs_cs, ivector)
#      38     imtx_cs_cs = pd.DataFrame(imtx_cs_cs)
#      39
#
# ~\AppData\Roaming\Python\Python36\site-packages\scipy\linalg\special_matrices.py in block_diag(*arrs)
#     544     r, c = 0, 0
#     545     for i, (rr, cc) in enumerate(shapes):
# --> 546         out[r:r + rr, c:c + cc] = arrs[i]
#     547         r += rr
#     548         c += cc
#
# KeyboardInterrupt:

# %%
country = 'IND'
# yyyy = 2008
row_level_one = country_codes.index(country)
# print(row_level_one)

a = np.arange(0,4914)

DVA_master_file = pd.DataFrame(a)
FVA_master_file = pd.DataFrame(a)
GRS_EX_master_file = pd.DataFrame(a)
GRS_OP_master_file = pd.DataFrame(a)

FWL_c = pd.DataFrame(industry_codes_20)
BWL_c = pd.DataFrame(industry_codes_20)
GVC_index_c = pd.DataFrame(industry_codes_20)
FWL_BWL_ratio_c = pd.DataFrame(industry_codes_20)
DVA_c = pd.DataFrame(industry_codes_20)
FVA_c = pd.DataFrame(industry_codes_20)
Gross_exports_c = pd.DataFrame(industry_codes_20)
GO_country_c = pd.DataFrame(industry_codes_20)
ex_intensity = pd.DataFrame(industry_codes_20)
DVX_c = pd.DataFrame(industry_codes_20)

FWL_c = FWL_c.rename(columns={ 0 : country})
BWL_c = BWL_c.rename(columns={ 0 : country})
GVC_index_c = GVC_index_c.rename(columns={ 0 : country})
FWL_BWL_ratio_c = FWL_BWL_ratio_c.rename(columns={ 0 : country})
DVA_c = DVA_c.rename(columns={ 0 : country})
FVA_c = FVA_c.rename(columns={ 0 : country})
Gross_exports_c = Gross_exports_c.rename(columns={ 0 : country})
GO_country_c = GO_country_c.rename(columns={ 0 : country})
ex_intensity = ex_intensity.rename(columns={ 0 : country})
DVX_c = DVX_c.rename(columns={ 0 : country})

start_year = 1990
end_year = 2015

start1 = datetime.now()

for i in range(start_year,end_year+1):
    DVA_country, FVA_country,GO_country,GE_country,FWL,BWL,GVC_index,FWL_BWL_ratio,DVA_country_modified,FVA_country_modified,DVX_country_modified, GE_country_modified,end,GO_country_modified , export_intensity = dva_calculations_loop(country, i, row_level_one,industry_codes_26) 

    DVA_master_file[i] = DVA_country.copy()
    FVA_master_file[i] = FVA_country.copy()
    GRS_EX_master_file[i] = GE_country.copy()
    GRS_OP_master_file[i] = GO_country.copy()
    
    FWL_c[i] = FWL.copy()
    BWL_c[i] = BWL.copy()
    GVC_index_c[i] = GVC_index.copy()
    FWL_BWL_ratio_c[i] = FWL_BWL_ratio.copy()
    DVA_c[i] = DVA_country_modified.copy()
    FVA_c[i] = FVA_country_modified.copy()
    Gross_exports_c[i] = GE_country_modified.copy()
    GO_country_c[i] = GO_country_modified.copy()
    ex_intensity[i] = export_intensity.copy()
    DVX_c[i] = DVX_country_modified.copy()
    
    
    print("the year ",i)
    
filename_1 = "MASTER_FILE_" + "DVA" + ".csv"
filename_2 = "MASTER_FILE_" + "FVA" + ".csv"
filename_3 = "MASTER_FILE_" + "GROSS_EXPORT" + ".csv"
filename_4 = "MASTER_FILE_" + "GROSS_OUTPUT" + ".csv"

DVA_master_file.to_csv(filename_1, index= False)
FVA_master_file.to_csv(filename_1, index= False)
GRS_EX_master_file.to_csv(filename_1, index= False)
GRS_OP_master_file.to_csv(filename_1, index= False)


filename_a = "Z_" + str(country) + "_FWL" + ".csv"
filename_b = "Z_" + str(country) + "_BWL" + ".csv"
filename_c = "Z_" + str(country) + "_GVC_index" + ".csv"
filename_d = "Z_" + str(country) + "_FWL_BWL_ratio" + ".csv"
filename_e = "Z_" + str(country) + "_DVA" + ".csv"
filename_f = "Z_" + str(country) + "_FVA" + ".csv"
filename_g = "Z_" + str(country) + "_Gross_exports" + ".csv"
filename_h = "Z_" + str(country) + "_Gross_ouput" + ".csv"
filename_i = "Z_" + str(country) + "_Export_intensity" + ".csv"
filename_j = "Z_" + str(country) + "_DVX" + ".csv"

FWL_c.to_csv(filename_a, index= False)
BWL_c.to_csv(filename_b, index= False)
GVC_index_c.to_csv(filename_c, index= False)
FWL_BWL_ratio_c.to_csv(filename_d, index= False)
DVA_c.to_csv(filename_e, index= False)
FVA_c.to_csv(filename_f, index= False)
Gross_exports_c.to_csv(filename_g, index= False)
GO_country_c.to_csv(filename_h, index= False)
ex_intensity.to_csv(filename_i, index= False)
DVX_c.to_csv(filename_j, index= False)

# DVA_country, FVA_country,GO_country,GE_country,FWL,BWL,GVC_index,FWL_BWL_ratio,DVA_country_modified,FVA_country_modified, GE_country_modified,end = dva_calculations_loop(country, yyyy, row_level_one,industry_codes_26) 

end = datetime.now()
print(end - start1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:199: RuntimeWarning: invalid value encountered in true_divide
# the year  1990
# the year  1991
# the year  1992
# the year  1993
# the year  1994
# the year  1995
# the year  1996
# the year  1997
# the year  1998
# the year  1999
# the year  2000
# the year  2001
# the year  2002
# the year  2003
# the year  2004
# the year  2005
# the year  2006
# the year  2007
# the year  2008
# the year  2009
# the year  2010
# the year  2011
# the year  2012
# the year  2013
# the year  2014
# the year  2015
# 0:31:22.730976

# %%
row_level_one = country_codes.index(country)
print(row_level_one)
# Out:
# 78

# %%
data_T.iloc[26*78:26*79,26*78:26*79] #T dimension is 4914*4914
# Out:
#               2028          2029         2030          2031          2032  \
# 2028  3.323100e+07    2354.70000      453.980  3.934500e+07  1.433300e+07
# 2029  8.570800e+00  284410.00000       47.765  1.431500e+06  7.729300e+03
# 2030  4.238900e+01       2.24580   235750.000  2.069900e+05  7.797300e+04
# 2031  2.733900e+06   43131.00000     1117.300  1.570600e+07  7.448000e+04
# 2032  1.398700e+05   42860.00000       53.551  6.380100e+04  2.985800e+06
# 2033  3.320700e+04   33772.00000   190820.000  7.847400e+05  3.848100e+05
# 2034  1.540300e+07  144420.00000  3593900.000  2.085600e+06  5.116700e+06
# 2035  1.065000e+05   52288.00000   861080.000  3.948500e+05  4.244500e+05
# 2036  3.121700e+05       6.74430  1723500.000  4.539700e+05  9.759800e+05
# 2037  4.042700e+04  530820.00000   210750.000  2.284700e+03  8.084200e+03
# 2038  2.039100e+04       0.33366   173970.000  3.794800e+03  6.560500e+04
# 2039  6.208200e+04   10114.00000     9478.100  1.343400e+06  2.959800e+05
# 2040  3.043800e+06    6988.00000  1719100.000  5.468400e+05  1.500000e+06
# 2041  4.796100e+05       0.48475  2031300.000  2.790600e+05  2.258300e+05
# 2038  1.910100e+06       0.28798  5.668000e+05   9080.100000  2.606000e+06
# 2039  1.268800e+04       0.77463  1.083900e+03     15.547000  4.461900e+03
# 2040  1.371500e+06     891.12000  1.450300e+05    868.710000  2.493200e+05
# 2041  7.337500e+06       0.31928  6.266300e+05   2526.400000  7.250800e+05
# 2042  8.050900e+04    5335.00000  6.267500e+04    101.660000  2.917600e+04
# 2043  1.037700e+06   68762.00000  8.078100e+05   1310.300000  3.760400e+05
# 2044  2.307900e+06  152940.00000  1.796700e+06   2914.200000  8.363800e+05
# 2045  3.356300e+06   14076.00000  9.086100e+05    628.220000  1.803000e+05
# 2046  4.029900e+06  945940.00000  2.542700e+06   3527.800000  1.012500e+06
# 2047  1.952000e+06   93237.00000  2.996100e+05    447.410000  1.284100e+05
# 2048  7.769000e+06  151750.00000  3.653900e+06   3982.100000  1.142900e+06
# 2049  2.121900e+00       0.21987  4.699200e-01      0.000605  1.736200e-01
# 2050  6.339800e+05   46989.00000  9.493200e+05    341.940000  9.813700e+04
# 2051  9.605800e+03     770.31000  1.503800e+04      5.605600  1.608800e+03
# 2052  2.756900e+06  221080.00000  4.315800e+06   1608.800000  4.617200e+05
# 2053  1.453100e+00       0.17452  2.759100e-01      0.000359  1.030000e-01
#
#              2053
# 2028   213.880000
# 2029    22.514000
# 2030    51.552000
# 2031  1798.100000
# 2032    26.346000
# 2033    27.794000
# 2034   187.550000
# 2035    58.528000
# 2036   290.900000
# 2037    92.606000
# 2038     9.436500
# 2039    56.779000
# 2040    34.635000
# 2041    19.238000
# 2042     0.274180
# 2043     3.533800
# 2044     7.859700
# 2045    21.130000
# 2046    36.807000
# 2047     7.763500
# 2048    62.817000
# 2049    13.711000
# 2050    17.442000
# 2051     0.008509
# 2052     2.442200
# 2053    51.193000
#
# [26 rows x 26 columns]

# %%
start = datetime.now()
country = 'IND'
yyyy = 2008

data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA,country_codes, country_list,industry_codes_26,industry_codes_6 = load_dataset(yyyy)


# data_FD[data_FD < 0] = 0
# data_T[data_T < 0] = 0

FD = np.sum(np.reshape(data_FD.values,(ncntry*nsec+1, nfd,-1), order='F'),axis=1)        # 1140 columns
FD = pd.DataFrame(FD)

# %%
label_VA.iloc[:,6*78:6*79]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
GO_cs[26*78:26*79]
Amat.iloc[26*78:26*79,26*78:26*79]
TiVA[26*78:26*79,26*78:26*79]
# Out:
# array([[3.43108131e+08],
#        [1.19295534e+07],
#        [5.93180372e+07],
#        [8.96845119e+07],
#        [4.86792024e+07],
#        [2.66925348e+07],
#        [2.45013166e+08],
#        [1.55928777e+08],
#        [1.41987039e+08],
#        [3.73935905e+07],
#        [2.72374411e+07],
#        [1.86265701e+07],
#        [9.07589646e+07],
#        [2.13460140e+08],
#        [6.17471442e+06],
#        [7.95857692e+07],
#        [1.77009171e+08],
#        [5.51924260e+07],
#        [2.72583165e+08],
#        [2.77194083e+07],
#        [2.22868013e+08],
#        [6.71499525e+07],
#        [6.72309470e+07],
#        [2.07845530e+05],
#        [5.96513165e+07],
#        [7.71980776e+03]])

# %%
EXGR_DVX_cs[26*78:26*79]
# Out:
# array([[ 1.06730073e+07],
#        [ 1.74036548e+05],
#        [ 8.86555613e+06],
#        [ 5.70981504e+05],
#        [ 1.48274709e+06],
#        [ 9.12871987e+05],
#        [ 7.87299455e+06],
#        [ 6.48611307e+06],
#        [ 2.52626525e+06],
#        [ 1.61616980e+05],
#        [ 2.98667464e+05],
#        [ 5.92838903e+05],
#        [ 2.85762354e+06],
#        [ 9.29969526e+05],
#        [ 2.09339092e+05],
#        [ 2.69816519e+06],
#        [ 6.00105646e+06],
#        [ 5.81265769e+05],
#        [ 4.39423866e+06],
#        [ 9.20901488e+05],
#        [ 8.10469685e+06],
#        [ 2.39202231e+04],
#        [ 4.73318316e+05],
#        [ 5.29805299e+03],
#        [ 1.52053490e+06],
#        [-2.28523517e+03]])

# %%
start = datetime.now()
country = 'IND'
yyyy = 2008

data_FD, data_Q, data_T,data_VA,data_QY , label_FD,label_Q,label_T,label_VA,country_codes, country_list,industry_codes_26,industry_codes_6 = load_dataset(yyyy)


# data_FD[data_FD < 0] = 0
# data_T[data_T < 0] = 0

FD = np.sum(np.reshape(data_FD.values,(ncntry*nsec+1, nfd,-1), order='F'),axis=1)        # 1140 columns
FD = pd.DataFrame(FD)

va_total_cs = np.sum(data_VA , axis =0)
va_total_cs = np.asarray(va_total_cs)

#Intermediate Demand
GRTR_INT_cs_cs = data_T.iloc[0:ncntry*nsec,0:ncntry*nsec]
#Final Demand
GRTR_FNL_cs_c = FD.iloc[0:ncntry*nsec,0:ncntry]
#Value added
VALU_cs = va_total_cs[0:ncntry*nsec]


#  (B) Identity matrices for summing across sectors (when calculating totals by country)

imtx_cs_c= np.ones((nsec,1))
ivector=np.ones((nsec,1))
for i in range(0,ncntry -1):
    imtx_cs_c = scipy.linalg.block_diag(imtx_cs_c, ivector)
imtx_cs_c = pd.DataFrame(imtx_cs_c)
    
imtx_cs_cs= np.ones((nsec,nsec))
ivector=np.ones((nsec,nsec))
for i in range(0,ncntry -1):
    imtx_cs_cs = scipy.linalg.block_diag(imtx_cs_cs, ivector)
imtx_cs_cs = pd.DataFrame(imtx_cs_cs)


imtx_c_cs= np.ones((1,nsec))
ivector = np.ones((1,nsec))
for i in range(0,ncntry -1):
    imtx_c_cs = scipy.linalg.block_diag(imtx_c_cs, ivector)
imtx_c_cs = pd.DataFrame(imtx_c_cs)


imtx_c_c= np.eye(ncntry)
imtx_c_c = pd.DataFrame(imtx_c_c)

imtx_cs_ck= np.ones((nsec,nfd))
ivector=np.ones((nsec,nfd))
for i in range(0,ncntry -1):
    imtx_cs_ck = scipy.linalg.block_diag(imtx_cs_ck, ivector)
imtx_cs_ck = pd.DataFrame(imtx_cs_ck)

#  (C) Calculating Gross Ouput (GO)

# Without statistical discrepancy

GO_INT_part = np.sum(np.reshape(GRTR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
GO_INT_part = pd.DataFrame(GO_INT_part)

GO_cs_c = GO_INT_part + GRTR_FNL_cs_c
GO_cs = np.sum(GO_cs_c,axis=1)
GO_cs = np.asarray(GO_cs).reshape(4914,1)

GO_c_c = np.dot(imtx_c_cs,GO_cs_c)
GO_c = np.sum(np.multiply(np.matlib.repmat(GO_cs, 1, ncntry),imtx_cs_c) ,axis=0)


################################
GGO_INT_part = np.sum(GRTR_INT_cs_cs, axis =0)
GGO_cs = GGO_INT_part + VALU_cs
GGO_cs = np.asarray(GGO_cs).reshape(4914,1)
###############################
#The above GGO files are just for cross check purposes to check the discrepancy the the gross ouput by adding row-wise
#and by adding column wise

VALU_cs = np.asarray(VALU_cs).reshape(4914,1)
VALU_c = np.sum(np.multiply(np.matlib.repmat(VALU_cs, 1, ncntry),imtx_cs_c) ,axis=0)

Inputs_cs = np.sum(GRTR_INT_cs_cs,axis=0)
Inputs_cs = np.asarray(Inputs_cs).reshape(4914,1)
Inputs_c = np.sum(np.multiply(np.matlib.repmat(Inputs_cs, 1, ncntry),imtx_cs_c) ,axis=0)
VALU_derived_cs = GO_cs - Inputs_cs
VALU_derived_cs = np.asarray(VALU_derived_cs).reshape(4914,1)

VALU_derived_c = np.sum(np.multiply(np.matlib.repmat(VALU_derived_cs, 1, ncntry),imtx_cs_c) ,axis=0)

# (E) Gross Exports
#  Gross exports of intermediate goods and services from domestic
#  sector s in country c

EXGR_INT_cs_cs = np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec)) - imtx_cs_cs))
EXGR_INT_cs_c = np.sum(np.reshape(EXGR_INT_cs_cs.values,(ncntry*nsec, nsec,-1), order='F'), axis=1)
EXGR_INT_cs_c = pd.DataFrame(EXGR_INT_cs_c)
EXGR_INT_cs = np.sum(EXGR_INT_cs_c,axis = 1)
temp_EXGR_INT_cs = EXGR_INT_cs.copy()
EXGR_INT_cs = np.asarray(EXGR_INT_cs).reshape(4914,1)
EXGR_INT_c = np.sum(np.multiply(np.matlib.repmat(EXGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)

# % Gross exports of final demand goods and services from domestic
# sector s in country c
EXGR_FNL_cs_c =np.multiply(GRTR_FNL_cs_c ,(np.ones((ncntry*nsec,ncntry)) - imtx_cs_c))
EXGR_FNL_cs = np.sum(np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry)) - imtx_cs_c)), axis =1)
temp_EXGR_FNL_cs = EXGR_FNL_cs.copy()
EXGR_FNL_cs = np.asarray(EXGR_FNL_cs).reshape(4914,1)

EXGR_FNL_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FNL_cs, 1, ncntry),imtx_cs_c) ,axis=0)
EXGR_cs_c = EXGR_INT_cs_c + EXGR_FNL_cs_c
EXGR_c_c = np.dot(imtx_c_cs,EXGR_cs_c)

# % Total gross exports (country-sector x 1)
EXGR_cs = temp_EXGR_INT_cs + temp_EXGR_FNL_cs

# % Total gross exports (country x 1)
EXGR_c = EXGR_INT_c + EXGR_FNL_c


# %% (F) Gross Imports: (Imported Intermediates)
# % Gross Imports of Intermediates (by country-sector, and by country)

IMGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs,(np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis =0)
IMGR_INT_cs = np.asarray(IMGR_INT_cs).reshape(4914,1)
IMGR_INT_c = np.sum(np.multiply(np.matlib.repmat(IMGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)

#  % Gross Imports of Final Demand goods and services (by country)
IMGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c, (np.ones((ncntry*nsec,ncntry))-imtx_cs_c)), axis = 0)

# % Total gross imports (by country)
IMGR_c = IMGR_INT_c + IMGR_FNL_c
#an array of 189 elements

# %% (G) Gross trade balance  
BALGR_c = EXGR_c - IMGR_c

# %% (H) Demand for Domestic Inputs (Use of Domestic Intermediates)    
# % Gross Domestic Intermediate demand for domestic inputs by country-sector
DDGR_INT_cs = np.sum(np.multiply(GRTR_INT_cs_cs , imtx_cs_cs),axis = 0)
DDGR_INT_cs = np.asarray(DDGR_INT_cs).reshape(4914,1)
DDGR_INT_c = np.sum(np.multiply(np.matlib.repmat(DDGR_INT_cs, 1, ncntry),imtx_cs_c) ,axis=0)


# % Gross Domestic Final demand of domestic inputs by country-sector
DDGR_FNL_c = np.sum(np.multiply(GRTR_FNL_cs_c,imtx_cs_c),axis = 0)


# %% (I) Domestic and Foreign Final Demand

GRTR_FNL_DOM_cs_c = np.multiply(GRTR_FNL_cs_c,imtx_cs_c)
GRTR_FNL_DOM_cs = np.sum(GRTR_FNL_DOM_cs_c,axis = 1)

# B)  Without statistical discrepancy

# % By sector
GRTR_FNL_DOM_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], imtx_cs_ck)
# % Sum across the thrid dimension, across countries for each of the 6 components of final demand
GRTR_FNL_DOM_cs_nfd = np.sum(np.reshape(GRTR_FNL_DOM_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis = 2)


GRTR_FNL_FOR_cs_c = np.multiply(GRTR_FNL_cs_c , (np.ones((ncntry*nsec,ncntry))-imtx_cs_c))
GRTR_FNL_FOR_cs = np.sum(GRTR_FNL_FOR_cs_c,axis=1)

# % By sector
GRTR_FNL_FOR_cs_ck = np.multiply(data_FD.iloc[0:ncntry*nsec,0:ncntry*nfd], (np.ones((ncntry*nsec,ncntry*nfd))-imtx_cs_ck))
# % Sum across the thrid dimension, across countries for each of the 6 components of final demand
GRTR_FNL_FOR_cs_nfd = np.sum(np.reshape(GRTR_FNL_FOR_cs_ck.values,(ncntry*nsec,nfd,-1),order='F'),axis=2)


# %% (J) Compute the VA vector indirectly (just to check that no problems with inverses)
# abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
# d = np.transpose(abc)

GO_cs = np.asarray(GO_cs).reshape(4914,1)
GGO_cs[4106] = 1
# A discrepancy in the data due to which we were unable to move ahead with the calculations

abc = np.matlib.repmat(GO_cs, 1, ncntry*nsec)
Amat = np.divide(GRTR_INT_cs_cs ,np.transpose(abc))

Amat = Amat.fillna(0)
Amat[Amat < 0] = 0

# % VA shares

va_vec_cs = np.ones((nsec*ncntry,1)) - np.asarray(np.sum(Amat,axis=0)).reshape(nsec*ncntry,1)
V_hat = np.eye(ncntry*nsec) - np.diag(np.sum(Amat , axis=0))

# % Leontief inverse
IminusA=np.eye(ncntry*nsec)-Amat
Bmat=np.linalg.inv(IminusA)
# % Leontief inverse

# % Total Value Added by country-sector
BY=np.matmul(Bmat,np.sum(GRTR_FNL_cs_c,axis=1))
va_cs= np.multiply(va_vec_cs,BY)

# %% (K) DVA and FVA of gross exports (From V*B*E)

TiVA_temp = np.matmul(V_hat,Bmat)
TiVA=np.matmul( TiVA_temp,np.diag(EXGR_cs))
#Here TiVA is the F matrix 
#F = V x L x E

EXGR_DVA_cs = np.sum(np.multiply(TiVA,imtx_cs_cs), axis=0)
EXGR_DVA_cs = np.asarray(EXGR_DVA_cs).reshape(4914,1)

EXGR_FVA_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=0)
EXGR_FVA_cs = np.asarray(EXGR_FVA_cs).reshape(4914,1)

EXGR_DVX_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=1)
EXGR_DVX_cs = np.asarray(EXGR_DVX_cs).reshape(4914,1)

# EXGR_DVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_DVA_cs, 1, ncntry), imtx_cs_c),axis=0)
# EXGR_FVA_c = np.sum(np.multiply(np.matlib.repmat(EXGR_FVA_cs, 1, ncntry), imtx_cs_c),axis=0)

EXGR_cs = np.asarray(EXGR_cs).reshape(4914,1)

DVA_country = EXGR_DVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
FVA_country = EXGR_FVA_cs[nsec*row_level_one:nsec*(row_level_one+1)]
GO_country = GO_cs[nsec*row_level_one:nsec*(row_level_one+1)]
GE_country = EXGR_cs[nsec*row_level_one:nsec*(row_level_one+1)]
GI_country = IMGR_INT_cs[nsec*row_level_one:nsec*(row_level_one+1)]

DVA_country_modified = modify_array_data_for_20(DVA_country)
FVA_country_modified = modify_array_data_for_20(FVA_country)
GE_country_modified = modify_array_data_for_20(GE_country)

FWL = DVA_country_modified/GE_country_modified
BWL = FVA_country_modified/GE_country_modified

#GVC participation index

GVC_index = ((FWL + BWL) * 100)/GE_country_modified
FWL_BWL_ratio = FWL/BWL

#UPstreamness calculation
UI2_temp = np.matmul(Bmat,GO_cs)
UI2 = UI2_temp/GO_cs
UI2_country = UI2[nsec*row_level_one:nsec*(row_level_one+1)]

#calculating UI for 20 industries

GO_country_modified = modify_array_data_for_20(GO_country)
GO_country_modified = GO_country_modified.reshape(20,1)
temp1 = GRTR_INT_cs_cs.iloc[nsec*row_level_one:nsec*(row_level_one+1),nsec*row_level_one:nsec*(row_level_one+1)].copy()
###################################
#Converting the data from 26 industries to 20 industries
###########################################

#Reducing Industries
#sn = starting number .... number for the first industry which is Agriculture
sn = row_level_one*26

#Adding Industry 1 & 2 ....i.e. Agriculture and Fishing
#Rename as Agriculture,Hunting,Forestry and Fishing
temp1[sn] = temp1[sn] + temp1[sn+1]
# deleting useless column
# df = df.drop('column_name', 1)

temp1 = temp1.drop(sn+1,1)
#deleting the fishing column

#Adding Industry 11 & 12 ....i.e. Other Manufacturing and Recycling
#Rename as Manufacturing, nec; recycling
temp1[sn+10] = temp1[sn+10] + temp1[sn+11]
temp1 = temp1.drop(sn+11,1)#deleting the Recycling column

#Deleting maintainance and repair (15), Private Households (24) and Re-export & Re-import (26)
temp1 = temp1.drop(sn+14,1) 
temp1 = temp1.drop(sn+23,1)
temp1 = temp1.drop(sn+25,1)

#Adding Industry 16 & 17 ....i.e. wholesale trade and retail trade.....
#Rename as Trade
temp1[sn+15] = temp1[sn+15] + temp1[sn+16]
temp1 = temp1.drop(sn+16,1)#deleting the Recycling column

#The new table with modified industries is ready column wise

#Now we need to add the data in similar fashion row wise

#Adding Industry 1 & 2 ....i.e. Agriculture and Fishing
#Rename as Agriculture,Hunting,Forestry and Fishing
temp1.loc[sn] = temp1.loc[sn] + temp1.loc[sn+1]

temp1 = temp1.drop(sn+1,0)#deleting the fishing column

temp1.loc[sn+10] = temp1.loc[sn+10] + temp1.loc[sn+11]
temp1 = temp1.drop(sn+11,0)#deleting the Recycling column

#Deleting maintainance and repair (15), Private Households (24) and Re-export & Re-import (26)
temp1 = temp1.drop(sn+14,0) 
temp1 = temp1.drop(sn+23,0)
temp1 = temp1.drop(sn+25,0)

#Adding Industry 16 & 17 ....i.e. wholesale trade and retail trade.....
#Rename as Trade
temp1.loc[sn+15] = temp1.loc[sn+15] + temp1.loc[sn+16]
temp1 = temp1.drop(sn+16,0)

#THe modified Input output table is ready
# io_table = temp1.copy()
abc_new = np.matlib.repmat(GO_country_modified, 1, len(GO_country_modified))
# abc_new = pd.DataFrame(abc_new)
temp1 = temp1.to_numpy()
Amat_new = np.divide(temp1 ,np.transpose(abc_new))

# % Leontief inverse
IminusA_ = np.eye(20)-Amat_new
Bmat_new =np.linalg.inv(IminusA_)

UI1_temp = np.matmul(Bmat_new,GO_country_modified)
UI1_country_20 = UI1_temp/GO_country_modified
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:186: RuntimeWarning: invalid value encountered in true_divide
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:244: RuntimeWarning: invalid value encountered in true_divide

# %%
EXGR_DVX_cs = np.sum(np.multiply(TiVA , (np.ones((ncntry*nsec,ncntry*nsec))-imtx_cs_cs)),axis=1)
EXGR_DVX_cs = np.asarray(EXGR_DVX_cs).reshape(4914,1)

# %%
# UI1_country_20 = pd.DataFrame(UI1_country_20)
# UI1_country_20.to_csv('zz_20_industries.csv', index= False)

# %%
UI1_country_20
# Out:
# array([[1.65403204],
#        [2.8838991 ],
#        [1.60778776],
#        [1.15139502],
#        [2.50046738],
#        [2.30123772],
#        [2.62705203],
#        [1.6811106 ],
#        [1.74642338],
#        [1.86757937],
#        [2.96616604],
#        [1.2829575 ],
#        [1.76733849],
#        [1.83616546],
#        [1.8235868 ],
#        [1.89564052],
#        [1.86646421],
#        [1.00002775],
#        [1.21501991],
#        [1.99113573]])

# %% [markdown]
# # Upstreamness Index

# %%
###Calculating UI

# matrix_1 = Yj/ Yi

p = pd.DataFrame(np.matlib.repmat(GO_country, 1, nsec))
p = np.transpose(p)
p = np.divide(p,GO_country)
p = np.transpose(p)

# Matrix 2 ...the open economy D ij vector cap

numerator = GO_country.copy()
denominator = GO_country - GE_country + GI_country

multiplier = np.divide(numerator,denominator)

io_table = Amat.iloc[nsec*row_level_one:nsec*(row_level_one+1),nsec*row_level_one:nsec*(row_level_one+1)]

#OEA = open economy adjusted 

oea_io_table = io_table*multiplier

#Now calculating the delta matrix
# df.mul(df3.c, axis=0)
delta = np.multiply(oea_io_table,p)

I = np.identity(nsec)
# one_vector = np.ones(35)
one_vector = np.ones(nsec).reshape((nsec, 1))

# We use numpy.linalg.inv() function to calculate the inverse of a matrix.

temp = I - delta
temp2 = np.linalg.inv(temp)
upstream_value = np.matmul(temp2,one_vector)
upstream_value
# Out:
# array([[9.87608553e+03],
#        [1.47917342e+01],
#        [2.15420299e+02],
#        [3.97503615e+03],
#        [8.74301439e+01],
#        [4.32860124e+01],
#        [2.98848948e+03],
#        [1.07815064e+03],
#        [1.14456397e+03],
#        [8.87540281e+01],
#        [2.16445974e+01],
#        [4.63460251e+01],
#        [3.65555614e+02],
#        [3.00230932e+02],
#        [1.92842226e+00],
#        [1.55234222e+02],
#        [7.63952455e+02],
#        [9.54742839e+01],
#        [1.79340789e+03],
# 2043 -1.663020e-03 -1.213887e-03 -1.422630e-02 -2.414407e+00 -8.412305e-03
# 2044 -8.226269e-03 -6.004973e-03 -7.037501e-02 -1.194316e+01 -4.161453e-02
# 2045 -4.047556e-03 -1.869887e-04 -1.204111e-02 -8.710799e-01 -3.035172e-03
# 2046 -2.206734e-02 -5.705889e-02 -1.530058e-01 -2.221129e+01 -7.739379e-02
# 2047 -1.098280e-03 -5.778639e-04 -1.852450e-03 -2.894363e-01 -1.008527e-03
# 2048  9.645857e-01 -7.619850e-03 -1.830321e-01 -2.087084e+01 -7.272393e-02
# 2049 -2.879388e-09  1.000000e+00 -7.007389e-09 -9.438628e-07 -3.288747e-09
# 2050 -8.385175e-04 -6.845999e-04  9.862023e-01 -5.199967e-01 -1.811860e-03
# 2051 -3.895688e-08 -3.441282e-08 -6.701896e-07  9.999739e-01 -9.107687e-08
# 2052 -3.208860e-03 -2.834545e-03 -5.520115e-02 -2.153010e+00  9.924982e-01
# 2053 -1.692926e-13 -2.239710e-13 -3.532377e-13 -4.807620e-11 -1.675079e-13
#
#              2053
# 2028 -1249.751835
# 2029    -4.494625
# 2030   -60.690932
# 2031 -3085.848970
# 2032   -54.678865
# 2033   -12.111373
# 2034  -863.305747
# 2035  -158.092551
# 2036  -751.062431
# 2037   -62.128398
# 2038    -4.851517
# 2039   -21.114408
# 2040   -51.229424
# 2041   -65.323479
# 2042    -0.028414
# 2043    -4.720087
# 2044   -23.349328
# 2045   -21.238026
# 2046  -167.984259
# 2047    -3.640603
# 2048  -238.656563
# 2049   -15.506970
# 2050   -19.227169
# 2051    -0.000029
# 2052    -2.369155
# 2053     0.995029
#
# [26 rows x 26 columns]

# %%
a = np.sum(Amat, axis=0)
print(a[26*78:26*79])
print("    ")
print(EXGR_DVA_cs[26*78:26*79])
# Out:
# 2028    0.243723
# 2029    0.146587
# 2030    0.323574
# 2031    0.884478
# 2032    0.857412
# 2033    0.682209
# 2034    0.814193
# 2035    0.718520
# 2036    0.821146
# 2037    0.917217
# 2038    0.833920
# 2039    0.785302
# 2040    0.602747
# 2041    0.578509
# 2042    0.176181
# 2043    0.176180
# 2044    0.176181
# 2045    0.723370
# 2046    0.640071
# 2047    0.227757
# 2048    0.212554
# 2049    0.025418
# 2050    0.391983
# 2051    0.224012
# 2052    0.224016
# 2053    1.725311
# dtype: float64
#
# [[ 1.09231183e+07]
#  [ 2.71758041e+05]
#  [ 1.00364617e+07]
#  [ 1.38075749e+07]
#  [ 2.86946068e+07]
#  [ 2.30902567e+06]
#  [ 4.33192700e+07]
#  [ 1.59206743e+07]
#  [ 2.53777714e+07]
#  [ 5.09821403e+06]
#  [ 6.55814831e+06]
#  [ 4.01051423e+06]
#  [ 1.12747277e+05]
#  [ 9.06382750e+05]
#  [ 7.48452716e+04]
#  [ 9.64674073e+05]
#  [ 2.14556098e+06]
#  [ 4.74599283e+06]
#  [ 8.28445374e+06]
#  [ 7.70052750e+05]
#  [ 6.45200428e+06]
#  [ 2.55294934e+05]
#  [ 1.07100918e+06]
#  [ 1.94140205e+00]
#  [ 5.57177026e+02]
#  [-2.85588130e+03]]
